# %%
import math
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
from scipy import integrate
import scipy.io as sio
import matplotlib.colors
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
mat = sio.loadmat('screen_dU/Di_30/r_cpeb.mat')
np.shape(mat['r_cpeb'])
# Out:
# (2, 38, 41)

# %%
x = np.arange(20,400,10)
U = np.linspace(-4,4,41)

rate = np.transpose(mat['r_cpeb'][0])
np.shape(rate)
#plt.figure(figsize=(8,6))
plt.figure(figsize=(6.5,6))

Reds = cm.get_cmap('bwr', 100)
mycmap = matplotlib.colors.ListedColormap(Reds(range(100)))
a=np.logspace(-0.06, 0.06, num=101, endpoint=True, base=10)
norm = matplotlib.colors.BoundaryNorm(a, len(a)-1)
levels=np.logspace(-0.06, 0.06, num=101, endpoint=True, base=10)

manual_l=[(50,0),(150,0),(200,0),(350,0)]

CS=plt.contour(x,U,rate,levels=[1.04,1.07,1.1, 1.13],colors='k')
plt.clabel(CS, inline=1, fontsize=14,fmt='%.2f',inline_spacing=10,manual=manual_l)
plt.contourf(x,U,rate,levels=levels,norm=norm, cmap=mycmap)


plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlim(0,410)
plt.ylim(-4,4)
plt.xlabel("M", fontsize=24)
plt.ylabel("$U_0/k_BT$", fontsize=24)
# cbar=plt.colorbar(ticks=[round(np.min(rate),2),1.0,1.04,1.07,1.1, 1.13,round(np.max(rate),2)])
# cbar.set_label(label="$c^B_M/c^B_s$",size=20)
# cbar.ax.tick_params(labelsize=16)
plt.tight_layout()
#plt.savefig("U_D30_cpeb_k2.png")
plt.savefig("al_U_D30_cpeb_k2.png")

# %%
x = np.arange(20,400,10)
U = np.linspace(-4,4,41)

rate = np.transpose(mat['r_cpeb'][1])
np.shape(rate)
#plt.figure(figsize=(8,6))
plt.figure(figsize=(6.5,6))


Reds = cm.get_cmap('bwr', 100)
mycmap = matplotlib.colors.ListedColormap(Reds(range(100)))
a=np.logspace(-0.01, 0.01, num=101, endpoint=True, base=10)
norm = matplotlib.colors.BoundaryNorm(a, len(a)-1)
levels=np.logspace(-0.01, 0.01, num=101, endpoint=True, base=10)

manual_l=[(100,3),(150,1),(200,0),(250,-3)]
CS=plt.contour(x,U,rate,levels=[1.0,1.005, 1.01, 1.015],colors='k')
plt.clabel(CS, inline=1, fontsize=14,fmt='%.3f',inline_spacing=10,manual=manual_l)
plt.contourf(x,U,rate,levels=levels,norm=norm, cmap=mycmap)



plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlim(0,410)
plt.ylim(-4,4)
plt.xlabel("M", fontsize=24)
plt.ylabel("$U_0/k_BT$", fontsize=24)
# cbar=plt.colorbar(ticks=[round(np.min(rate),3),1.0, 1.005,1.01, 1.015, round(np.max(rate),3)])
# cbar.set_label(label="$c^B_M/c^B_s$",size=20)
# cbar.ax.tick_params(labelsize=16)
plt.tight_layout()
#plt.savefig("U_D30_cpeb_k0.2.png")
plt.savefig("al_U_D30_cpeb_k0.2.png")

# %%
mat = sio.loadmat('screen_dU/Di_30/r_rim.mat')
np.shape(mat['r_rim'])
# Out:
# (2, 38, 41)

# %%
x = np.arange(20,400,10)
U = np.linspace(-4,4,41)

rate = np.transpose(mat['r_rim'][0])
np.shape(rate)
#plt.figure(figsize=(8,6))
plt.figure(figsize=(6.5,6))

Reds = cm.get_cmap('bwr', 100)
mycmap = matplotlib.colors.ListedColormap(Reds(range(100)))
a=np.logspace(-3, 3, num=101, endpoint=True, base=10)
norm = matplotlib.colors.BoundaryNorm(a, len(a)-1)
levels=np.logspace(-3, 3, num=101, endpoint=True, base=10)

manual_l=[(300,3.5),(230,0),(150,-2),(80,-3)]

CS=plt.contour(x,U,rate,levels=[0.01,0.1,1,5],colors='k')
plt.clabel(CS, inline=1, fontsize=14,fmt='%.0e',inline_spacing=10,manual=manual_l)
plt.contourf(x,U,rate,levels=levels,norm=norm, cmap=mycmap)


plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlim(0,410)
plt.ylim(-4,4)
plt.xlabel("M", fontsize=24)
plt.ylabel("$U_0/k_BT$", fontsize=24)
# cbar=plt.colorbar(ticks=[round(np.min(rate),3),0.010,0.1,1.0,5.0,round(np.max(rate),3)],format='%.0e')
# cbar.set_label(label="$c^B_M/c^B_s$",size=20)
# cbar.ax.tick_params(labelsize=16)
plt.tight_layout()
#plt.savefig("U_D30_rim_k2.png")
plt.savefig("al_U_D30_rim_k2.png")

# %%
x = np.arange(20,400,10)
U = np.linspace(-4,4,41)

rate = np.transpose(mat['r_rim'][1])
np.shape(rate)
#plt.figure(figsize=(8,6))
plt.figure(figsize=(6.5,6))

Reds = cm.get_cmap('bwr', 100)
mycmap = matplotlib.colors.ListedColormap(Reds(range(100)))
a=np.logspace(-2.2, 2.2, num=101, endpoint=True, base=10)
norm = matplotlib.colors.BoundaryNorm(a, len(a)-1)
levels=np.logspace(-2.2, 2.2, num=101, endpoint=True, base=10)

manual_l=[(300,3.5),(200,-1),(100,-3)]

CS=plt.contour(x,U,rate,levels=[0.1,1,10],colors='k')
plt.clabel(CS, inline=1, fontsize=14,fmt='%.0e',inline_spacing=10,manual=manual_l)
plt.contourf(x,U,rate,levels=levels,norm=norm, cmap=mycmap)


plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlim(0,410)
plt.ylim(-4,4)
plt.xlabel("M", fontsize=24)
plt.ylabel("$U_0/k_BT$", fontsize=24)
# cbar=plt.colorbar(ticks=[round(np.min(rate),3),0.1,1.0,10,round(np.max(rate),3)],format='%.0e')
# cbar.set_label(label="$c^B_M/c^B_s$",size=20)
# cbar.ax.tick_params(labelsize=16)
plt.tight_layout()
#plt.savefig("U_D30_rim_k0.2.png")
plt.savefig("al_U_D30_rim_k0.2.png")
