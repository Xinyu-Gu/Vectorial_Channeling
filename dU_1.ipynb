# %%
import math
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
from scipy import integrate
import scipy.io as sio
import matplotlib.colors
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
mat = sio.loadmat('screen_dU/Di_1/r_cpeb.mat')
np.shape(mat['r_cpeb'])
# Out:
# (2, 38, 41)

# %%
x = np.arange(20,400,10)
U = np.linspace(-4,4,41)

rate = np.transpose(mat['r_cpeb'][0])
np.shape(rate)
#plt.figure(figsize=(8,6))
plt.figure(figsize=(6.5,6))

Reds = cm.get_cmap('bwr', 100)
mycmap = matplotlib.colors.ListedColormap(Reds(range(100)))
a=np.logspace(-0.2, 0.2, num=101, endpoint=True, base=10)
norm = matplotlib.colors.BoundaryNorm(a, len(a)-1)
levels=np.logspace(-0.2, 0.2, num=101, endpoint=True, base=10)

manual_l=[(50,0),(150,0),(350,0)]

CS=plt.contour(x,U,rate,levels=[1.1, 1.2, 1.4],colors='k')
plt.clabel(CS, inline=1, fontsize=14,fmt='%.1f',inline_spacing=10,manual=manual_l)
plt.contourf(x,U,rate,levels=levels,norm=norm, cmap=mycmap)


plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlim(0,410)
plt.ylim(-4,4)
plt.xlabel("M", fontsize=24)
plt.ylabel("$U_0/k_BT$", fontsize=24)
# cbar=plt.colorbar(ticks=[1.0, 1.1, 1.2, 1.4,round(np.max(rate),1)])
# cbar.set_label(label="$c^B_M/c^B_s$",size=20)
# cbar.ax.tick_params(labelsize=16)
plt.tight_layout()
#plt.savefig("U_D1_cpeb_k2.png")
plt.savefig("al_U_D1_cpeb_k2.png")

# %%
x = np.arange(20,400,10)
U = np.linspace(-4,4,41)

rate = np.transpose(mat['r_cpeb'][1])
np.shape(rate)
#plt.figure(figsize=(8,6))
plt.figure(figsize=(6.5,6))


Reds = cm.get_cmap('bwr', 100)
mycmap = matplotlib.colors.ListedColormap(Reds(range(100)))
a=np.logspace(-0.02, 0.02, num=101, endpoint=True, base=10)
norm = matplotlib.colors.BoundaryNorm(a, len(a)-1)
levels=np.logspace(-0.02, 0.02, num=101, endpoint=True, base=10)

manual_l=[(50,3),(100,1),(200,0),(300,-2)]
CS=plt.contour(x,U,rate,levels=[1.0, 1.01, 1.02, 1.03],colors='k')
plt.clabel(CS, inline=1, fontsize=14,fmt='%.2f',inline_spacing=10,manual=manual_l)
plt.contourf(x,U,rate,levels=levels,norm=norm, cmap=mycmap)




plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlim(0,410)
plt.ylim(-4,4)
plt.xlabel("M", fontsize=24)
plt.ylabel("$U_0/k_BT$", fontsize=24)
# cbar=plt.colorbar(ticks=[round(np.min(rate),3),1.0, 1.01, 1.02, 1.03,round(np.max(rate),3)])
# cbar.set_label(label="$c^B_M/c^B_s$",size=20)
# cbar.ax.tick_params(labelsize=16)
plt.tight_layout()
#plt.savefig("U_D1_cpeb_k0.2.png")
plt.savefig("al_U_D1_cpeb_k0.2.png")

# %%
mat = sio.loadmat('screen_dU/Di_1/r_rim.mat')
np.shape(mat['r_rim'])
# Out:
# (2, 38, 41)

# %%
x = np.arange(20,400,10)
U = np.linspace(-4,4,41)

rate = np.transpose(mat['r_rim'][0])
np.shape(rate)
#plt.figure(figsize=(8,6))
plt.figure(figsize=(6.5,6))

Reds = cm.get_cmap('bwr', 100)
mycmap = matplotlib.colors.ListedColormap(Reds(range(100)))
a=np.logspace(-5, 5, num=101, endpoint=True, base=10)
norm = matplotlib.colors.BoundaryNorm(a, len(a)-1)
levels=np.logspace(-5, 5, num=101, endpoint=True, base=10)

manual_l=[(300,3.5),(250,1),(200,-1),(100,-3)]

CS=plt.contour(x,U,rate,levels=[0.0001,0.001,0.01,0.1],colors='k')
plt.clabel(CS, inline=1, fontsize=14,fmt='%.0e',inline_spacing=10,manual=manual_l)
plt.contourf(x,U,rate,levels=levels,norm=norm, cmap=mycmap)


plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlim(0,410)
plt.ylim(-4,4)
plt.xlabel("M", fontsize=24)
plt.ylabel("$U_0/k_BT$", fontsize=24)
# cbar=plt.colorbar(ticks=[1e-4,0.001,0.01,0.1,1.0, np.min(rate)],format='%.0e')
# cbar.set_label(label="$c^B_M/c^B_s$",size=20)
# cbar.ax.tick_params(labelsize=16)
plt.tight_layout()
#plt.savefig("U_D1_rim_k2.png")
plt.savefig("al_U_D1_rim_k2.png")

# %%
x = np.arange(20,400,10)
U = np.linspace(-4,4,41)

rate = np.transpose(mat['r_rim'][1])
np.shape(rate)
#plt.figure(figsize=(8,6))
plt.figure(figsize=(6.5,6))

Reds = cm.get_cmap('bwr', 100)
mycmap = matplotlib.colors.ListedColormap(Reds(range(100)))
a=np.logspace(-4, 4, num=101, endpoint=True, base=10)
norm = matplotlib.colors.BoundaryNorm(a, len(a)-1)
levels=np.logspace(-4, 4, num=101, endpoint=True, base=10)

manual_l=[(300,3.5),(250,1),(200,-1),(100,-3)]

CS=plt.contour(x,U,rate,levels=[0.001,0.01,0.1,1],colors='k')
plt.clabel(CS, inline=1, fontsize=14,fmt='%.0e',inline_spacing=10,manual=manual_l)
plt.contourf(x,U,rate,levels=levels,norm=norm, cmap=mycmap)


plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlim(0,410)
plt.ylim(-4,4)
plt.xlabel("M", fontsize=24)
plt.ylabel("$U_0/k_BT$", fontsize=24)
# cbar=plt.colorbar(ticks=[0.001,0.01,0.1,1.0,np.min(rate),np.max(rate)],format='%.0e')
# cbar.set_label(label="$c^B_M/c^B_s$",size=20)
# cbar.ax.tick_params(labelsize=16)
plt.tight_layout()
#plt.savefig("U_D1_rim_k0.2.png")
plt.savefig("al_U_D1_rim_k0.2.png")
